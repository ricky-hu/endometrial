# %% [markdown]
# ## loading necessary libraries and data

# %%
#loading all the necessary libraries
import numpy as np
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")
sns.set()
from scipy import stats
stats.chisqprob = lambda chisq, df: stats.chi2.sf(chisq, df)

# %%
#using the panda library to load the data
data=pd.read_csv('BMIF_803_Assignment_5_data.csv')

# %%
#visualize the data
data
# Out:
#     Patient  SMAD4  TP53  genes_altered_gt_4  OS_months  \
# 0      5001      0     1                   0         32
# 1      5002      1     0                   0         28
# 2      5003      1     1                   1         32
# 3      5004      1     1                   0          5
# 4      5005      0     0                   1         30
# 5      5006      1     1                   0         31
# 6      5007      1     1                   0         29
# 7      5008      0     0                   1         30
# 8      5009      0     1                   1          7
# 9      5010      0     1                   1         27
# 10     5011      1     1                   1         11
# 11     5013      0     1                   1         17
# 12     5014      0     0                   0         25
# 13     5015      0     0                   0         21
# 14     5016      1     1                   0         20
# 15     5017      0     1                   0         15
# 16     5019      1     1                   1         22
# 17     5020      1     1                   1         22
# 18     5021      1     0                   1         22
# 19     5022      0     1                   1         21
# 20     5023      0     0                   0         21
# 21     5024      0     0                   0         21
# 22     5025      0     0                   0         17
# 23     5026      1     1                   0          7
# 24     5027      0     0                   1          5
# 25     5028      0     1                   1         18
# 26     5029      0     0                   0         15
# 27     5030      1     1                   0         17
# 28     5031      1     0                   0         17
# 29     5033      0     0                   0         15
# 30     5034      0     1                   0          6
# 31     5035      1     0                   1          3
# 32     5037      1     1                   0         16
# 33     5038      0     1                   0         16
# 34     5039      1     1                   1         15
#
#     OS_status (death=1, alive=0)       GLCM15         GLCM16       RLM2  \
# 0                              0  1537.178269   20786.027650  20.846151
# 1                              0  3238.837432   58714.389330  27.085880
# 2                              0  1449.381439   20204.802550  22.525364
# 3                              1   808.426463   10022.371090  17.994915
# 4                              0  1897.336017   27887.793120  23.066161
# 5                              0  1143.384164   15333.522880  17.425245
# 6                              0   963.233436   11928.110880  18.300306
# 7                              0  3522.316626   57437.540080  27.544492
# 8                              1  1768.428128   26353.790340  23.238776
# 9                              0  1140.142199   16123.320260  20.390301
# 10                             1  2330.622426   36760.260390  24.853239
# 11                             0   126.645875     849.400017   8.088148
# 12                             0  3455.939492   60356.218200  29.730389
# 13                             0  2744.289291   42383.281200  24.717135
# 14                             0  1283.142614   16322.745400  17.794074
# 15                             1  1218.541541   14397.886440  16.614374
# 16                             0  2897.669348   44803.152460  26.266278
# 17                             0  1696.218553   25655.259260  22.496746
# 18                             0   922.739847   13398.272050  19.694493
# 19                             0  3199.524694   51911.955860  27.906302
# 20                             0  2285.606242   34977.313140  24.561572
# 21                             0  2181.513800   35386.960060  25.515904
# 22                             0  1932.959667   28167.207650  23.588157
# 23                             0  1890.478749   27779.243940  24.281972
# 24                             1   678.441998    8354.075484  16.215176
# 25                             0  2227.165417   33380.009300  24.303968
# 26                             0  4491.188392   81434.074390  31.729335
# 27                             0  5337.911207  100110.406000  33.222144
# 28                             0  2136.558149   32554.307020  23.770622
# 29                             0  4268.863581   76971.935080  31.617825
# 30                             0  2006.811674   29706.318510  22.880355
# min                        0.000000   126.645875     849.400017   8.088148
# 25%                        0.000000  1366.262027   18263.773975  20.618226
# 50%                        0.000000  2006.811674   29706.318510  23.770622
# 75%                        0.000000  2957.696377   46549.474010  26.155019
# max                        1.000000  5337.911207  100110.406000  33.222144
#
#              IH3  ...     LBP103     LBP105      FD1_11      FD1_29  \
# count  35.000000  ...  35.000000  35.000000   35.000000   35.000000
# mean   -0.036481  ...   0.002488   0.002420  149.605576   87.156733
# std     0.221637  ...   0.001767   0.001865   20.528042   18.647608
# min    -0.444077  ...   0.000000   0.000000   73.246958   41.149084
# 25%    -0.201171  ...   0.001612   0.001409  140.378056   76.481107
# 50%    -0.017525  ...   0.002444   0.002136  153.695078   86.622998
# 75%     0.087253  ...   0.003428   0.003468  161.627630  101.701859
# max     0.414572  ...   0.007660   0.007660  181.180386  130.272342
#
#           FD1_30      FD1_41      FD1_44     ACM1_1     ACM1_2     ACM1_3
# count  35.000000   35.000000   35.000000  35.000000  35.000000  35.000000
# mean   30.451923  157.915812  178.700432   0.007755  34.827686   0.062483
# std    15.562572   20.934685   22.422374   0.003143   4.157362   0.034243
# min     6.500000   78.638684   88.521554   0.004912  23.595139  -0.003537
# 25%    17.083333  150.480520  173.408811   0.005769  32.010457   0.039250
# 50%    27.000000  162.933718  182.859675   0.006405  35.914374   0.062032
# 75%    41.458333  169.118323  189.981185   0.009376  37.765596   0.084141
# max    64.125000  191.498544  207.813248   0.019267  42.584953   0.143508
#
# [8 rows x 41 columns]

# %% [markdown]
# ## briefly have some idea how our data look like

# %%
# in this exercise we are interested in SMAD4 data set
data['SMAD4'].value_counts(normalize=True).plot.bar()

# %%
# to plot our radiomic data
radio_data=data.iloc[:,6:] # we are choosing only the radiomic data 
#using a seaborn plot in a library we plot all our radiomic features. 
#the key here is too see if you datasets have some very large outliers.
for i, column in enumerate(radio_data.columns): 
    plt.figure(i)
    sns.distplot(radio_data[column])

# %%
# measuring the relation between the radiomic features and our target variable SMAD4
radio_temp=radio_data.copy()
haha=radio_temp.describe()
for column, ColData in haha.iteritems():
    bins=[haha[column].iloc[[3][-1]],haha[column].iloc[[4][-1]], 
      haha[column].iloc[[5][-1]], haha[column].iloc[[6][-1]], haha[column].iloc[[7][-1]]]
    bins
    group=['low', 'mlow', 'medium', 'high']
    radio_temp[column+'_bin']=pd.cut(radio_temp[column], bins, labels=group)
    sorting=pd.crosstab(radio_temp[column+'_bin'], data['SMAD4'])
    sorting.div(sorting.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True)
    plt.xlabel(column)
    plt.ylabel('percentage')

# %% [markdown]
# ## Multicolinearity
# we need to check if our data sets is colinear (co-dependent of each other)

# %%
#we can plot the colinearity as the matrix to seeif our data is colinear
#any colinearity above +/- 0.9 is undesirable 
app=data.corr()

app.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_553e4eb2_33d3_11ea_be4c_433ad8da83d6row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_553e4eb2_33d3_11ea_be4c_433ad8da83d6row0_col1 {
#             background-color:  #a3c2fe;
#             color:  #000000;
#         }    #T_553e4eb2_33d3_11ea_be4c_433ad8da83d6row0_col2 {
#             background-color:  #7093f3;
#             color:  #000000;
#         }    #T_553e4eb2_33d3_11ea_be4c_433ad8da83d6row0_col3 {
#             background-color:  #7597f6;
#             color:  #000000;
#         }    #T_553e4eb2_33d3_11ea_be4c_433ad8da83d6row0_col4 {
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }    #T_553e4eb2_33d3_11ea_be4c_433ad8da83d6row0_col5 {
#             background-color:  #a7c5fe;
#             color:  #000000;
#         }    #T_553e4eb2_33d3_11ea_be4c_433ad8da83d6row0_col6 {
#             background-color:  #f4c6af;
#             color:  #000000;
#         }    #T_553e4eb2_33d3_11ea_be4c_433ad8da83d6row0_col7 {
#             background-color:  #f2cbb7;
#             color:  #000000;
#         }    #T_553e4eb2_33d3_11ea_be4c_433ad8da83d6row0_col8 {
#             background-color:  #f2cbb7;
#             color:  #000000;
#         }    #T_553e4eb2_33d3_11ea_be4c_433ad8da83d6row0_col9 {
#             background-color:  #6384eb;
#             color:  #000000;
#         }    #T_553e4eb2_33d3_11ea_be4c_433ad8da83d6row0_col10 {
#             background-color:  #d5dbe5;
#             color:  #000000;
#         }    #T_553e4eb2_33d3_11ea_be4c_433ad8da83d6row0_col11 {
#             background-color:  #cdd9ec;
#             color:  #000000;
#         }    #T_553e4eb2_33d3_11ea_be4c_433ad8da83d6row0_col12 {
#             background-color:  #c4d5f3;
#             color:  #000000;
#         }    #T_553e4eb2_33d3_11ea_be4c_433ad8da83d6row0_col13 {
#             background-color:  #d6dce4;
#             color:  #000000;
#         }    #T_553e4eb2_33d3_11ea_be4c_433ad8da83d6row0_col14 {
#             background-color:  #d8dce2;
#             color:  #000000;
#         }    #T_553e4eb2_33d3_11ea_be4c_433ad8da83d6row0_col15 {
#             background-color:  #a6c4fe;
#             color:  #000000;
#         }    #T_553e4eb2_33d3_11ea_be4c_433ad8da83d6row0_col16 {
#             background-color:  #6a8bef;
#             color:  #000000;
#         }    #T_553e4eb2_33d3_11ea_be4c_433ad8da83d6row0_col17 {
#             background-color:  #c4d5f3;
#             color:  #000000;
#         }    #T_553e4eb2_33d3_11ea_be4c_433ad8da83d6row0_col18 {
#             background-color:  #a2c1ff;
#             color:  #000000;
#         }    #T_553e4eb2_33d3_11ea_be4c_433ad8da83d6row0_col19 {
#             background-color:  #7b9ff9;
#             color:  #000000;
#         }    #T_553e4eb2_33d3_11ea_be4c_433ad8da83d6row0_col20 {
#             background-color:  #98b9ff;
#             color:  #000000;
#         }    #T_553e4eb2_33d3_11ea_be4c_433ad8da83d6row0_col21 {
#             background-color:  #6b8df0;
#             color:  #000000;
#         }    #T_553e4eb2_33d3_11ea_be4c_433ad8da83d6row0_col22 {
#             background-color:  #9abbff;
#             color:  #000000;
#         }    #T_553e4eb2_33d3_11ea_be4c_433ad8da83d6row0_col23 {
#             background-color:  #81a4fb;
#             color:  #000000;
#         }    #T_553e4eb2_33d3_11ea_be4c_433ad8da83d6row0_col24 {
#             background-color:  #e7d7ce;
#             color:  #000000;
#         }    #T_553e4eb2_33d3_11ea_be4c_433ad8da83d6row0_col25 {
#             background-color:  #ebd3c6;
#             color:  #000000;
#         }    #T_553e4eb2_33d3_11ea_be4c_433ad8da83d6row0_col26 {
#             background-color:  #e1dad6;
#             color:  #000000;
#         }    #T_553e4eb2_33d3_11ea_be4c_433ad8da83d6row0_col27 {
#             background-color:  #f7bca1;
#             color:  #000000;
#         }    #T_553e4eb2_33d3_11ea_be4c_433ad8da83d6row0_col28 {
#             background-color:  #f1cdba;
#             color:  #000000;
#         }    #T_553e4eb2_33d3_11ea_be4c_433ad8da83d6row0_col29 {
#             background-color:  #b7cff9;
#             color:  #000000;
#         }    #T_553e4eb2_33d3_11ea_be4c_433ad8da83d6row0_col30 {
#             background-color:  #5f7fe8;
#             color:  #000000;
#         }    #T_553e4eb2_33d3_11ea_be4c_433ad8da83d6row0_col31 {
#             background-color:  #4f69d9;
#             color:  #000000;
#         }    #T_553e4eb2_33d3_11ea_be4c_433ad8da83d6row0_col32 {
#             background-color:  #4c66d6;
#             color:  #000000;
#         }    #T_553e4eb2_33d3_11ea_be4c_433ad8da83d6row0_col33 {
#             background-color:  #ead5c9;
#             color:  #000000;
#         }    #T_553e4eb2_33d3_11ea_be4c_433ad8da83d6row0_col34 {
#             background-color:  #e6d7cf;
#             color:  #000000;
#         }    #T_553e4eb2_33d3_11ea_be4c_433ad8da83d6row0_col35 {
#             background-color:  #d1dae9;
#             color:  #000000;
#         }    #T_553e4eb2_33d3_11ea_be4c_433ad8da83d6row0_col36 {
#             background-color:  #ead4c8;
#             color:  #000000;
#         }    #T_553e4eb2_33d3_11ea_be4c_433ad8da83d6row0_col37 {
#             background-color:  #e4d9d2;
#             color:  #000000;
#         }    #T_553e4eb2_33d3_11ea_be4c_433ad8da83d6row0_col38 {
#             background-color:  #bad0f8;
#             color:  #000000;
#         }    #T_553e4eb2_33d3_11ea_be4c_433ad8da83d6row0_col39 {
#             background-color:  #b9d0f9;
#             color:  #000000;
#         }    #T_553e4eb2_33d3_11ea_be4c_433ad8da83d6row0_col40 {
#             background-color:  #c1d4f4;
#             color:  #000000;
#         }    #T_553e4eb2_33d3_11ea_be4c_433ad8da83d6row1_col0 {
#             background-color:  #aec9fc;
#             color:  #000000;
#         }    #T_553e4eb2_33d3_11ea_be4c_433ad8da83d6row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_553e4eb2_33d3_11ea_be4c_433ad8da83d6row1_col2 {
#             background-color:  #d1dae9;
#             color:  #000000;
#         }    #T_553e4eb2_33d3_11ea_be4c_433ad8da83d6row1_col3 {
#             background-color:  #96b7ff;
#             color:  #000000;
#         }    #T_553e4eb2_33d3_11ea_be4c_433ad8da83d6row1_col4 {
#             background-color:  #b6cefa;
#             color:  #000000;
#         }    #T_553e4eb2_33d3_11ea_be4c_433ad8da83d6row1_col5 {
#             background-color:  #c3d5f4;
#             color:  #000000;
#         }    #T_553e4eb2_33d3_11ea_be4c_433ad8da83d6row1_col6 {
#             background-color:  #b6cefa;
#             color:  #000000;
#         }    #T_553e4eb2_33d3_11ea_be4c_433ad8da83d6row1_col7 {
#             background-color:  #b2ccfb;
#             color:  #000000;
#         }    #T_553e4eb2_33d3_11ea_be4c_433ad8da83d6row1_col8 {
#             background-color:  #b1cbfc;
#             color:  #000000;
#         }    #T_553e4eb2_33d3_11ea_be4c_433ad8da83d6row1_col9 {
#             background-color:  #c7d7f0;
#             color:  #000000;
#         }    #T_553e4eb2_33d3_11ea_be4c_433ad8da83d6row1_col10 {
#             background-color:  #799cf8;
#             color:  #000000;
#         }    #T_553e4eb2_33d3_11ea_be4c_433ad8da83d6row1_col11 {
#             background-color:  #5673e0;
#             color:  #000000;
#         }    #T_553e4eb2_33d3_11ea_be4c_433ad8da83d6row1_col12 {
#             background-color:  #5a78e4;
#             color:  #000000;
#         }    #T_553e4eb2_33d3_11ea_be4c_433ad8da83d6row1_col13 {
#             background-color:  #5875e1;
#             color:  #000000;
#         }    #T_553e4eb2_33d3_11ea_be4c_433ad8da83d6row1_col14 {
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }    #T_553e4eb2_33d3_11ea_be4c_433ad8da83d6row1_col15 {
#             background-color:  #5977e3;
#             color:  #000000;
#         }    #T_553e4eb2_33d3_11ea_be4c_433ad8da83d6row1_col16 {
#             background-color:  #f7b89c;
#             color:  #000000;
#         }    #T_553e4eb2_33d3_11ea_be4c_433ad8da83d6row1_col17 {
#             background-color:  #9bbcff;
#             color:  #000000;
#         }    #T_553e4eb2_33d3_11ea_be4c_433ad8da83d6row1_col18 {
#             background-color:  #

# %% [markdown]
# ### Colinearity
# One of a powerful method to detect the colinearity is Variance inflaction factor (VIF). It measures the R^2 value of each variable as the linear combination of the remaining variables. The VIF= 1/(1-R^2) which means  the larger the VIF the more colinear is the variable

# %%
#print out our radiomic feature names
radio_data.columns
# Out:
# Index(['GLCM15', 'GLCM16', 'RLM2', 'IH3', 'IH4', 'LBP10', 'LBP11', 'LBP13',
#        'LBP16', 'LBP29', 'LBP30', 'LBP37', 'LBP42', 'LBP43', 'LBP49', 'LBP52',
#        'LBP53', 'LBP54', 'LBP87', 'LBP88', 'LBP89', 'LBP90', 'LBP91', 'LBP98',
#        'LBP102', 'LBP103', 'LBP105', 'FD1_11', 'FD1_29', 'FD1_30', 'FD1_41',
#        'FD1_44', 'ACM1_1', 'ACM1_2', 'ACM1_3'],
#       dtype='object')

# %%
#the vif code is presented below and the result indicate that GLCM15 is the most colinear variable 
#It is a good idea to remove one highest VIF variable at the time and rerun this code 
from statsmodels.stats.outliers_influence import variance_inflation_factor
variables=radio_data[[ 'GLCM15', 'GLCM16', 'RLM2', 'IH3', 'IH4', 'LBP10', 'LBP11', 'LBP13',
       'LBP16', 'LBP29', 'LBP30', 'LBP37', 'LBP42', 'LBP43', 'LBP49', 'LBP52',
       'LBP53', 'LBP54', 'LBP87', 'LBP88', 'LBP89', 'LBP90', 'LBP91', 'LBP98',
       'LBP102', 'LBP103', 'LBP105', 'FD1_11', 'FD1_29', 'FD1_30', 'FD1_41',
       'FD1_44', 'ACM1_1', 'ACM1_2', 'ACM1_3' ]]
vif = pd.DataFrame()
vif['VIF']=[variance_inflation_factor(variables.values, i) for i in range(variables.shape[1])]
vif['Features']=variables.columns
vif
# Out:
#              VIF Features
# 0   8.311228e+05   GLCM15
# 1   2.131863e+05   GLCM16
# 2   1.323319e+06     RLM2
# 3   7.952245e+01      IH3
# 4   1.640285e+04      IH4
# 5   8.184333e+02    LBP10
# 6   2.408789e+03    LBP11
# 7   8.439315e+02    LBP13
# 8   6.929872e+01    LBP16
# 9   8.893166e+01    LBP29
# 10  5.779562e+01    LBP30
# 11  2.618809e+02    LBP37
# 12  3.347039e+02    LBP42
# 13  3.660704e+02    LBP43
# 14  1.439771e+03    LBP49
# 15  1.782149e+03    LBP52
# 16  5.120251e+02    LBP53
# 17  2.610581e+03    LBP54
# 18  1.824086e+03    LBP87
# 19  1.054033e+04    LBP88
# 20  1.793133e+03    LBP89
# 21  1.451420e+03    LBP90
# 22  6.756328e+03    LBP91
# 23  4.646319e+02    LBP98
# 24  8.050869e+02   LBP102
# 25  1.566400e+03   LBP103
# 26  1.087750e+03   LBP105
# 27  7.762084e+05   FD1_11
# 28  9.472914e+03   FD1_29
# 29  2.979834e+03   FD1_30
# 30  4.518826e+06   FD1_41
# 31  3.426857e+06   FD1_44
# 32  5.581447e+02   ACM1_1
# 33  4.387778e+04   ACM1_2
# 34  1.512888e+03   ACM1_3

# %%
#after a series of highly colinear variable have been removed.
from statsmodels.stats.outliers_influence import variance_inflation_factor
variables=radio_data[[ 'GLCM16',  'IH3', 'LBP10', 'LBP11', 'LBP13',
       'LBP16', 'LBP29', 'LBP30', 'LBP37', 'LBP42', 'LBP43', 'LBP49', 'LBP52',
       'LBP53', 'LBP54',  'LBP89',   'LBP98',
       'LBP102', 'LBP105',  'FD1_30', 
        'ACM1_1', 'ACM1_3' ]]
vif = pd.DataFrame()
vif['VIF']=[variance_inflation_factor(variables.values, i) for i in range(variables.shape[1])]
vif['Features']=variables.columns
vif
# Out:
#           VIF Features
# 0    9.034207   GLCM16
# 1    4.524074      IH3
# 2   19.794647    LBP10
# 3   35.704453    LBP11
# 4   39.904495    LBP13
# 5   22.275194    LBP16
# 6   10.002554    LBP29
# 7    5.234992    LBP30
# 8   38.517553    LBP37
# 9   15.403944    LBP42
# 10  17.534793    LBP43
# 11  75.908105    LBP49
# 12  20.765630    LBP52
# 13  10.492342    LBP53
# 14  32.845641    LBP54
# 15  67.672172    LBP89
# 16  71.698960    LBP98
# 17  60.378188   LBP102
# 18  41.900730   LBP105
# 19  24.077243   FD1_30
# 20  33.866542   ACM1_1
# 21   8.457469   ACM1_3

# %% [markdown]
# ## Feature selection
# now we need to reanalyze if the remaining variable have influence on the target variable.

# %%
#creating new dataframes for our non-colinear data
X= radio_data[[ 'GLCM16',  'IH3', 'LBP10', 'LBP11', 'LBP13',
       'LBP16', 'LBP29', 'LBP30', 'LBP37', 'LBP42', 'LBP43', 'LBP49', 'LBP52',
       'LBP53', 'LBP54',  'LBP89',   'LBP98',
       'LBP102', 'LBP105',  'FD1_30', 
        'ACM1_1', 'ACM1_3']]
y=data['SMAD4']
fil_data=pd.concat([X, y], axis=1)
fil_data
# Out:
#            GLCM16       IH3     LBP10     LBP11     LBP13     LBP16     LBP29  \
# 0    20786.027650  0.058762  0.004919  0.007275  0.007058  0.004888  0.003970
# 1    58714.389330  0.065277  0.003954  0.010058  0.003570  0.007134  0.001922
# 2    20204.802550  0.037621  0.000962  0.001381  0.004964  0.004079  0.001656
# 3    10022.371090  0.097021  0.002283  0.000000  0.002237  0.000000  0.000000
# 4    27887.793120  0.095995  0.004237  0.005873  0.005013  0.003951  0.003446
# 5    15333.522880  0.191919  0.006674  0.006992  0.010167  0.007942  0.002523
# 6    11928.110880 -0.017525  0.003986  0.009106  0.005200  0.000000  0.003906
# 7    57437.540080 -0.140245  0.005069  0.007264  0.004152  0.002849  0.003736
# 8    26353.790340  0.048493  0.006480  0.003430  0.007677  0.004723  0.001804
# 9    16123.320260  0.345098  0.010789  0.011781  0.007006  0.012318  0.000000
# 10   36760.260390  0.078510  0.003828  0.004970  0.005010  0.005844  0.000460
# 11     849.400017  0.414572  0.011142  0.009225  0.006947  0.009879  0.002159
# 12   60356.218200 -0.387152  0.013040  0.019013  0.014643  0.009357  0.004298
# 16  0.004488  0.002337  53.400000  0.004924  0.039090      1
# 17  0.006524  0.003930  32.333333  0.005787  0.072590      1
# 18  0.000000  0.000000   6.500000  0.019267 -0.003537      1
# 19  0.004920  0.002136  47.000000  0.004912  0.039409      0
# 20  0.003281  0.002012  38.000000  0.005461  0.039776      0
# 21  0.002500  0.002500   7.500000  0.015208  0.139458      0
# 22  0.004514  0.004427  35.000000  0.005317  0.054738      0
# 23  0.000000  0.000000  15.000000  0.009990  0.050559      1
# 24  0.003501  0.001959  64.125000  0.005752  0.102814      0
# 25  0.002241  0.002241  21.166667  0.007461  0.086574      0
# 26  0.000000  0.000000  25.333333  0.005924  0.032637      0
# 27  0.005842  0.003679  46.833333  0.005716  0.068573      1
# 28  0.004585  0.003489  21.833333  0.008004  0.065740      1
# 29  0.000000  0.000000   7.000000  0.011127  0.110222      0
# 30  0.000667  0.000667  27.000000  0.006405  0.143508      0
# 31  0.002363  0.001466  45.692308  0.005869  0.054202      1
# 32  0.002829  0.001860  22.833333  0.006299  0.010220      1
# 33  0.002488  0.002488  16.666667  0.009371  0.052069      0
# 34  0.003712  0.001369  59.600000  0.005384  0.085857      1
#
# [35 rows x 23 columns]

# %% [markdown]
# we will filter the data by focusing on the correlation between the radiomic data and the target SMAD4.

# %%
#in our datasets no radiomic features scored above 0.5 and only one feature scored above 0.46 
cor=fil_data.corr()
cor_target=abs(cor['SMAD4'])
relevant=cor_target[cor_target>0.3]
relevant
# Out:
# LBP11    0.350563
# LBP13    0.332281
# LBP16    0.412547
# LBP29    0.320575
# LBP30    0.460608
# LBP49    0.335600
# LBP89    0.425556
# SMAD4    1.000000
# Name: SMAD4, dtype: float64

# %%
#creating new dataframes for our non-colinear filtered  data
X= radio_data[[ 'LBP11', 'LBP13', 'LBP16', 'LBP29', 'LBP30',
        'LBP49','LBP89', ]]
y=data['SMAD4']
X2=X.copy()

# %% [markdown]
# ## Machine learning models

# %%
#Baysean model wrapped in the Kfold
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.naive_bayes import GaussianNB

i=1 
kf=StratifiedKFold(n_splits=5, random_state=2,shuffle=True)
for train_index, test_index in kf.split(X,y):
    print('\n {} of kfold {}'.format(i,kf.n_splits)) 
    x_train, x_test=X.loc[train_index], X.loc[test_index]
    y_train, y_test=y[train_index], y[test_index]
    model=GaussianNB()
    model.fit(x_train, y_train)
    pred_test=model.predict(x_test)
    score=accuracy_score(y_test, pred_test)
    confmat=confusion_matrix(y_test, pred_test)
    tn, fp, fn, tp = confusion_matrix(y_test, pred_test).ravel()
    spec=tn/(tn+fp)
    sens=tp/(tp+fn)
    print ('accuracy score is %.2f and the  confusion matrix is %s,  sensitivity is %.2f specificity is %.2f' 
           %( score, confmat,  sens, spec))
    from sklearn import metrics
    fpr, tpr, _ = metrics.roc_curve(y_test,  pred_test) 
    auc = metrics.roc_auc_score(y_test, pred_test) 
    plt.figure(figsize=(12,8)) 
    plt.plot(fpr,tpr,label="validation, auc="+str(auc)) 
    plt.xlabel('False Positive Rate') 
    plt.ylabel('True Positive Rate') 
    plt.legend(loc=4) 
    plt.show()
    i=i+1
# Out:
#  1 of kfold 5
# accuracy score is 0.75 and the  confusion matrix is [[2 2]
#  [0 4]],  sensitivity is 1.00 specificity is 0.50
#  2 of kfold 5
# accuracy score is 0.71 and the  confusion matrix is [[2 2]
#  [0 3]],  sensitivity is 1.00 specificity is 0.50
#  3 of kfold 5
# accuracy score is 0.57 and the  confusion matrix is [[3 1]
#  [2 1]],  sensitivity is 0.33 specificity is 0.75
#  4 of kfold 5
# accuracy score is 0.57 and the  confusion matrix is [[2 2]
#  [1 2]],  sensitivity is 0.67 specificity is 0.50
#  5 of kfold 5
# accuracy score is 1.00 and the  confusion matrix is [[3 0]
#  [0 3]],  sensitivity is 1.00 specificity is 1.00

# %%
from xgboost import XGBClassifier
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
from sklearn.metrics import auc
i=1 
kf=StratifiedKFold(n_splits=5, random_state=42,shuffle=True)
for train_index, test_index in kf.split(X,y):
    print('\n {} of kfold {}'.format(i,kf.n_splits)) 
    x_train, x_test=X.loc[train_index], X.loc[test_index]
    y_train, y_test=y[train_index], y[test_index]
    model=XGBClassifier(n_estimators=20, max_depth=4)
    model.fit(x_train, y_train)
    pred_test=model.predict(x_test)
    score=accuracy_score(y_test, pred_test)
    confmat=confusion_matrix(y_test, pred_test)
    tn, fp, fn, tp = confusion_matrix(y_test, pred_test).ravel()
    spec=tn/(tn+fp)
    sens=tp/(tp+fn)
    print ('accuracy score is %.2f and the  confusion matrix is %s,  sensitivity is %.2f specificity is %.2f' 
           %( score, confmat,  sens, spec))
    from sklearn import metrics
    fpr, tpr, _ = metrics.roc_curve(y_test,  pred_test) 
    auc = metrics.roc_auc_score(y_test, pred_test) 
    plt.figure(figsize=(12,8)) 
    plt.plot(fpr,tpr,label="validation, auc="+str(auc)) 
    plt.xlabel('False Positive Rate') 
    plt.ylabel('True Positive Rate') 
    plt.legend(loc=4) 
    plt.show()
    i=i+1
# Out:
#  1 of kfold 5
# accuracy score is 0.50 and the  confusion matrix is [[3 1]
#  [3 1]],  sensitivity is 0.25 specificity is 0.75
#  2 of kfold 5
# accuracy score is 0.29 and the  confusion matrix is [[1 3]
#  [2 1]],  sensitivity is 0.33 specificity is 0.25
#  3 of kfold 5
# accuracy score is 0.71 and the  confusion matrix is [[3 1]
#  [1 2]],  sensitivity is 0.67 specificity is 0.75
#  4 of kfold 5
# accuracy score is 0.57 and the  confusion matrix is [[3 1]
#  [2 1]],  sensitivity is 0.33 specificity is 0.75
#  5 of kfold 5
# accuracy score is 0.50 and the  confusion matrix is [[1 2]
#  [1 2]],  sensitivity is 0.67 specificity is 0.33

# %%
from sklearn.linear_model import LogisticRegression

from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

from sklearn.metrics import f1_score
from sklearn.metrics import recall_score
i=1 
kf=StratifiedKFold(n_splits=5, random_state=4,shuffle=True)
for train_index, test_index in kf.split(X,y):
    print('\n {} of kfold {}'.format(i,kf.n_splits)) 
    x_train, x_test=X.loc[train_index], X.loc[test_index]
    y_train, y_test=y[train_index], y[test_index]
    model=LogisticRegression()
    model.fit(x_train, y_train)
    pred_test=model.predict(x_test)
    score=accuracy_score(y_test, pred_test)
    confmat=confusion_matrix(y_test, pred_test)
    tn, fp, fn, tp = confusion_matrix(y_test, pred_test).ravel()
    spec=tn/(tn+fp)
    sens=tp/(tp+fn)
    print ('accuracy score is %.2f and the  confusion matrix is %s,  sensitivity is %.2f specificity is %.2f' 
           %( score, confmat,  sens, spec))
    from sklearn import metrics
    fpr, tpr, _ = metrics.roc_curve(y_test,  pred_test) 
    auc = metrics.roc_auc_score(y_test, pred_test) 
    plt.figure(figsize=(12,8)) 
    plt.plot(fpr,tpr,label="validation, auc="+str(auc)) 
    plt.xlabel('False Positive Rate') 
    plt.ylabel('True Positive Rate') 
    plt.legend(loc=4) 
    plt.show()
    i=i+1
# Out:
#  1 of kfold 5
# accuracy score is 0.50 and the  confusion matrix is [[4 0]
#  [4 0]],  sensitivity is 0.00 specificity is 1.00
#  2 of kfold 5
# accuracy score is 0.57 and the  confusion matrix is [[4 0]
#  [3 0]],  sensitivity is 0.00 specificity is 1.00
#  3 of kfold 5
# accuracy score is 0.57 and the  confusion matrix is [[4 0]
#  [3 0]],  sensitivity is 0.00 specificity is 1.00
#  4 of kfold 5
# accuracy score is 0.57 and the  confusion matrix is [[4 0]
#  [3 0]],  sensitivity is 0.00 specificity is 1.00
#  5 of kfold 5
# accuracy score is 0.50 and the  confusion matrix is [[3 0]
#  [3 0]],  sensitivity is 0.00 specificity is 1.00

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import tree
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score
i=1 
kf=StratifiedKFold(n_splits=5, random_state=4,shuffle=True)
for train_index, test_index in kf.split(X,y):
    print('\n {} of kfold {}'.format(i,kf.n_splits)) 
    x_train, x_test=X.loc[train_index], X.loc[test_index]
    y_train, y_test=y[train_index], y[test_index]
    model=tree.DecisionTreeClassifier(random_state=1)
    model.fit(x_train, y_train)
    pred_test=model.predict(x_test)
    pred_test=model.predict(x_test)
    score=accuracy_score(y_test, pred_test)
    confmat=confusion_matrix(y_test, pred_test)
    tn, fp, fn, tp = confusion_matrix(y_test, pred_test).ravel()
    spec=tn/(tn+fp)
    sens=tp/(tp+fn)
    print ('accuracy score is %.2f and the  confusion matrix is %s,  sensitivity is %.2f specificity is %.2f' 
           %( score, confmat,  sens, spec))
    from sklearn import metrics
    fpr, tpr, _ = metrics.roc_curve(y_test,  pred_test) 
    auc = metrics.roc_auc_score(y_test, pred_test) 
    plt.figure(figsize=(12,8)) 
    plt.plot(fpr,tpr,label="validation, auc="+str(auc)) 
    plt.xlabel('False Positive Rate') 
    plt.ylabel('True Positive Rate') 
    plt.legend(loc=4) 
    plt.show()
    i=i+1
# Out:
#  1 of kfold 5
# accuracy score is 0.62 and the  confusion matrix is [[3 1]
#  [2 2]],  sensitivity is 0.50 specificity is 0.75
#  2 of kfold 5
# accuracy score is 0.43 and the  confusion matrix is [[2 2]
#  [2 1]],  sensitivity is 0.33 specificity is 0.50
#  3 of kfold 5
# accuracy score is 0.57 and the  confusion matrix is [[2 2]
#  [1 2]],  sensitivity is 0.67 specificity is 0.50
#  4 of kfold 5
# accuracy score is 0.71 and the  confusion matrix is [[2 2]
#  [0 3]],  sensitivity is 1.00 specificity is 0.50
#  5 of kfold 5
# accuracy score is 0.17 and the  confusion matrix is [[0 3]
#  [2 1]],  sensitivity is 0.33 specificity is 0.00
